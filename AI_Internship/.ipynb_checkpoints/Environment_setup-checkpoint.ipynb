# %% [markdown]
# # Environment setup
# This notebook verifies my Python environment.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("matplotlib:", plt.__version__)
# Out:
# NumPy: 2.5.1
# Pandas: 3.0.3
# matplotlib: 3.11.1

# %%
# !pip freeze > requirements.txt
